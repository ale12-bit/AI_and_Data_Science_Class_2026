# %%
# 'Ai and data Science Assignment 2"
# "Alex Wanjiru"
# "AI and Data Science class of 2026"

# %%
my_name = "Alex Wanjiru"
print(my_name)
# Out:
# Alex Wanjiru

# %% [markdown]
# # New section

# %% [markdown]
# # New section
